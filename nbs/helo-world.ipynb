# %%
#%pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting charset_normalizer<4,>=2 (from requests)
#   Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl.metadata (37 kB)
# Requirement already satisfied: idna<4,>=2.5 in /Users/fabioceriaco/Documents/Trabalho/projetos/FastApi/Analytics_API/venv/lib/python3.14/site-packages (from requests) (3.11)
# Collecting urllib3<3,>=1.21.1 (from requests)
#   Downloading urllib3-2.6.3-py3-none-any.whl.metadata (6.9 kB)
# Collecting certifi>=2017.4.17 (from requests)
#   Downloading certifi-2026.1.4-py3-none-any.whl.metadata (2.5 kB)
# Using cached requests-2.32.5-py3-none-any.whl (64 kB)
# Using cached charset_normalizer-3.4.4-cp314-cp314-macosx_10_13_universal2.whl (207 kB)
# Downloading urllib3-2.6.3-py3-none-any.whl (131 kB)
# Downloading certifi-2026.1.4-py3-none-any.whl (152 kB)
# Installing collected packages: urllib3, charset_normalizer, certifi, requests
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [requests]
# Successfully installed certifi-2026.1.4 charset_normalizer-3.4.4 requests-2.32.5 urllib3-2.6.3
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
# import httpx

# %%
path = "/healthz"
base_url = "http://localhost:8000" # 127.0.0.1
endpoint = f'{base_url}{path}'
endpoint
# Out:
# 'http://localhost:8000/healthz'

# %%
response = requests.get(endpoint)
print(response.ok)
# Out:
# True
